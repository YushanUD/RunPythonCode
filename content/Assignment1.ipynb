# %% [markdown]
# # Assignment 1: Python and Pandas

# %% [markdown]
# In this assignment, you need to download a dataset and use Pandas to answer a number of questions about the dataset.
#
# - Create an account on [https://www.kaggle.com/](https://www.kaggle.com/) and download the `train.csv` file found at [https://www.kaggle.com/c/titanic/data](https://www.kaggle.com/c/titanic/data)
# - Read the data description at [https://www.kaggle.com/c/titanic/data](https://www.kaggle.com/c/titanic/data) to understand the dataset
# - Make sure your dataset is in the same folder as your script `.ipynb` and complete it by writing programs according to the inline comments and answer the questions.
#
# make sure your starter file extension is `.ipynb`

# %% [markdown]
# 1. read the titanic csv file into a data frame

# %%
# read the titanic csv file into a data frame

# %% [markdown]
# 2. how many rows and columns in the data frame?

# %%
# how many rows and columns in the data frame?

# %% [markdown]
# 3. what's the data type of columns PassengerId, Pclass? read the data description at https://www.kaggle.com/c/titanic/data and state what data types those two columns should have been and why?

# %%
# what's the data type of columns PassengerId, Pclass?

# %% [markdown]
# what data types those two columns should have been and why?

# %% [markdown]
# 4. show the first 10 rows of data in this cell

# %%
# show the first 10 rows of data in this cell

# %% [markdown]
# 5. select a sub dataframe which has row 20 - 40

# %%
# select a sub dataframe which has row 20 - 40

# %% [markdown]
# 6. select a sub dataframe to only show name, gender, age of the passengers

# %%
# select a sub dataframe to only show name, gender, age of the passengers

# %% [markdown]
# 7. calculate the average age of all passengers and print out 'The average age is : xx.x`
#
# Hint: use this method `df['column_name'].mean()`

# %%
# calculate the average age of all passengers and print out 'The average age is : xx.x`

# %% [markdown]
# 8. select rows 10 to 20 with columns name and age - use .iloc
#
# Hint: if you want to choose multiple columns that are not neighbours, use this way: `df.iloc[row_index1:row_index2, [col_index1,col_index2]]`

# %%
# select rows 10 to 20 with columns name and age - use .iloc

# %% [markdown]
# 9. show all survived female passengers under 18

# %%
# show all survived female passengers under 18

# %% [markdown]
# 10. show the total number of all survived female passengers under 18
#
# Hint: use `len(df)`

# %%
# show the total number of all survived female passengers under 18

# %% [markdown]
# 11. show all the ports where people can embark the trip (unique value of Embarked column)

# %%
# show how many people embarked from each port

# %% [markdown]
# 12. show survived passengers who embarked on port Queenstown (Q) or Southampton(S)
#
# hint: the expression should have the structure like `(survived) & ((Queenstown) | (Southampton))`

# %%
# show survived passengers who embarked on port Queenstown or Southampton
# hint: the expression should have the structure like () & (() | ())
