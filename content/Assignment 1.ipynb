# %% [markdown]
# # Assignment 1: Python and Pandas

# %% [markdown]
# ## Submission
#
# You need to submit the completed `.ipynb` notebook and the corresponding `.html` version to Canvas with:
#
# - the **code** you used to analyze the data
# - the run **results** for the code
# - the **answers to the questions** - you need to type your answers in Markdown - only showing the code and results is not enough

# %% [markdown]
# ### Project 1: Python
#
# Personal Budget Tracker: create a simple budget tracking tool. The goal is to practice using variables, input/output, lists or dictionaries, loops, and basic calculations.
# Your program should allow a user to:
#
# - **Input their monthly income.**
# - **Add expenses** in different categories (e.g., rent, food, entertainment, transportation).
# - **Store expenses** in a suitable data structure (list or dictionary).
# - **Calculate and display:**
#     - Total expenses
#     - Savings (income – total expenses)
#     - Percentage of income spent on each category
# - **Output a summary report** showing the above information in a clear format.
#
# **Requirements**
#
# - Use meaningful variable names.
# - Store expenses in a dictionary or list of tuples.
# - Write at least one function (e.g., to calculate percentages or print the report).
# - Ensure the program handles at least **4 different expense categories**.
# - Format the output so it is easy to read.
#
# ---
#
# ### Sample Run (for reference only)
#
# ```
# Enter your monthly income: 3000
#
# Enter an expense category (or type 'done' to finish): rent
# Enter amount for rent: 1200
# Enter an expense category (or type 'done' to finish): food
# Enter amount for food: 500
# Enter an expense category (or type 'done' to finish): entertainment
# Enter amount for entertainment: 300
# Enter an expense category (or type 'done' to finish): done
#
# ----- Monthly Budget Report -----
# Income: $3000
# Total Expenses: $2000
# Savings: $1000
#
# Breakdown by Category:
# - rent: $1200 (40.0%)
# - food: $500 (16.7%)
# - entertainment: $300 (10.0%)
# ```

# %% [markdown]
# ### Project 2: Pandas and Kaggle
#
# In this assignment, you need to download a dataset and use Pandas to answer a number of questions about the dataset.
#
# - Create an account on [https://www.kaggle.com/](https://www.kaggle.com/) and download the `train.csv` file found at [https://www.kaggle.com/c/titanic/data](https://www.kaggle.com/c/titanic/data)
# - Read the data description at [https://www.kaggle.com/c/titanic/data](https://www.kaggle.com/c/titanic/data) to understand the dataset
# - Make sure your dataset is in the same folder as your script `.ipynb` and complete it by writing programs according to the inline comments and answer the questions.
#
# make sure your starter file extension is `.ipynb`

# %%
# read the titanic csv file into a data frame

# %% [markdown]
# 1. how many rows and columns in the data frame?
# 1. which column(s) has missing values?
# 1. what's data type of columns PassengerId, Pclass? read the data description at https://www.kaggle.com/c/titanic/data and state what data types those two columns should have and why?

# %% [markdown]
# 4. show the first 10 rows of data in this cell

# %%
# show the first 10 rows of data in this cell

# %% [markdown]
# 5. select a sub dataframe which has row 20 - 40

# %%
# select a sub dataframe which has row 20 - 40

# %% [markdown]
# 6. select a sub dataframe to only show name, gender, age of the passengers

# %%
# select a sub dataframe to only show name, gender, age of the passengers

# %% [markdown]
# 7. calculate the average age of all passengers and print out 'The average age is : xx.x`

# %%
# calculate the average age of all passengers and print out 'The average age is : xx.x`

# %% [markdown]
# 8. select rows 10 to 20 with columns name and age - use .iloc

# %%
# select rows 10 to 20 with columns name and age - use .iloc

# %% [markdown]
# 9. show all survived female passengers under 18

# %%
# show all survived female passengers under 18

# %% [markdown]
# 10. show the total number of all survived female passengers under 18

# %%
# show the total number of all survived female passengers under 18

# %% [markdown]
# 11. show how many people embarked from each port

# %%
# show how many people embarked from each port

# %% [markdown]
# 12. show survived passengers who embarked on port Queenstown or Southampton\
#  hint: the expression should have the structure like () & (() | ())

# %%
# show survived passengers who embarked on port Queenstown or Southampton
# hint: the expression should have the structure like () & (() | ())
